# %% [markdown]
# ## Organized search for house locations that satisfy being historic and that have a golf course nearby
#
# There are around 30 golf courses in King County, WA. A raw list of golf courses and their locations (coordinates or zip codes) will be not an effective filter since among the requirements, the buyer also wants a house that is in a historic area. Most golf courses will be in the suburbs.
#
# For maximal effectiveness in the search, we can narrow down the areas that are historic, and that have a nearby golf course.
#
# The final data to be used as filter, is a list of zip codes that satisfy both conditions. That ZIP code can be used directly as a filter to the dataframe.
#
# Rather than Data Engineering, this is best done via searches in the internet and with AI tools.

# %% [markdown]
# An initial search via AI provides these zip codes with Golf Courses, that are located in districts that can be characterized as historic. The qualification as 'historic' is fuzzy and subject to interpretation - like having historic landmarks for example, and not a part of an 'official' historic-zipcode list.

# %%
import warnings

import matplotlib.pyplot as plt
import pandas as pd

warnings.filterwarnings("ignore")

# %%
# add the commands here to show the contents of king_county_historic_golf_zips.csv
df_golfzips = pd.read_csv("king_county_historic_golf_zips.csv")
df_golfzips.head(14)
# Out:
#     zipcode                    area_name  \
# 0     98118       Columbia City, Seattle
# 1     98144         Mount Baker, Seattle
# 2     98108         Beacon Hill, Seattle
# 3     98107             Ballard, Seattle
# 4     98116  West Seattle (Admiral/Alki)
# 5     98126  West Seattle (Golf/Genesee)
# 6     98125   Maple Leaf / North Seattle
# 7     98065                   Snoqualmie
# 8     98022                     Enumclaw
# 9     98010                Black Diamond
# 10    98011                      Bothell
# 11    98005                     Bellevue
#
#                                      golf_course_name  \
# 0           Bill Wright Golf Complex (Jefferson Park)
# 1           Bill Wright Golf Complex (Jefferson Park)
# 2           Bill Wright Golf Complex (Jefferson Park)
# 3                                Interbay Golf Center
# 4                            West Seattle Golf Course
# 5                            West Seattle Golf Course
# 6                            Jackson Park Golf Course
# 7                                Mount Si Golf Course
# 8                                Enumclaw Golf Course
# 9   Lake Wilderness Golf Course (Maple Valley, 98038)
# 10               Inglewood Golf Club (Kenmore, 98028)
# 11                               Bellevue Golf Course
#
#                                          why_historic
# 0   One of Seattle's eight officially designated h...
# 1   Olmsted-planned early-20th-century streetcar n...
# 2   Contains the Olmsted Brothers-designed Jeffers...
# 3   Ballard Avenue Historic District is on the Nat...
# 4   Historic Admiral district and Alki Point, site...
# 5   Adjacent ZIP containing the municipal course (...
# 6   Older north-Seattle housing stock near the his...
# 7   Historic downtown Snoqualmie and Snoqualmie Fa...
# 8   Historic early-1900s small-town downtown found...
# 9   National Register-listed former coal-mining to...
# 10  Historic downtown Bothell with preserved Main ...
# 11  Less a historic district than established mid-...
